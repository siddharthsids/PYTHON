# %% [markdown]
# **1.What are data structures, and why are they important?**
#
#  -Data structures are ways of organizing and storing data in a computer so it can be used efficiently. They are important because they make tasks like searching, inserting, and deleting data faster and more efficient. Choosing the right data structure can save time and memory, and is essential for solving problems effectively.

# %% [markdown]
# **2.  Explain the difference between mutable and immutable data types with examples?**
#
#    -Mutable data types can be changed after they are created. For example, lists and dictionaries are mutable because we can add, remove, or modify elements.
#
#    -Immutable data types cannot be changed after creation. Strings and tuples are examples.

# %% [markdown]
# **3. What are the main differences between lists and tuples in Python?**
#
#   -Lists are mutable, while tuples are immutable.
#
# Lists use square brackets [ ], while tuples use these brackets ( ).
#
# Tuples are faster to access and safer for data that should not change.
#
# Lists have more methods like append() or remove() which in tuples don’t have the option to change because of it's immutable nature.

# %% [markdown]
# ** 4. Describe how dictionaries store data.**
#
#   -Dictionaries store data as key-value pairs. Each key is hashed to find its position in memory like a unique address. This allows very fast lookups because Python can jump directly to where the value is stored using the key.

# %% [markdown]
# **5. Why might you use a set instead of a list in Python?**
#
#   -You would use a set when you need to store unique values without duplicates and when you want fast checking to see if an element exists. Sets are also useful for operations like union and intersection. It doesn't allow a value to be duplicated value.

# %% [markdown]
# **6. What is a string in Python, and how is it different from a list?**
#
#   -A string is a sequence of characters, while a list is a sequence of items which can be of any type. The main difference is that strings are immutable and they cannot be changed, but lists are mutable  that means you can change it.

# %% [markdown]
# **7. How do tuples ensure data integrity in Python?**
#
#   -Tuples are immutable, meaning their contents cannot be changed after creation. This ensures that the data remains the same throughout the program, preventing accidental modifications. It helps the data to be secure and it's immutable nature play a vital role in securing the data value.

# %% [markdown]
# **8. What is a hash table, and how does it relate to dictionaries in Python?**
#
#   -A hash table is a data structure that uses a hash function to store and retrieve data quickly. Python dictionaries are built on hash tables, which is why accessing or adding an item in a dictionary is usually very fast (O(1) time).

# %% [markdown]
# **9. Can lists contain different data types in Python?**
#
#   -Yes, lists can hold elements of different types. For example:

# %%
my_list = [155, "siddharth", 2.9, [1, 2]]

# %% [markdown]
# **10. Explain why strings are immutable in Python.**
#
#   -Strings are immutable because Python creates a new string each time we make a change. This makes them safe to use as keys in dictionaries and allows Python to optimize memory usage.

# %% [markdown]
# **11. What advantages do dictionaries offer over lists for certain tasks?**
#
#   -Dictionaries allow fast lookups using keys (like student["name"]), whereas lists require searching through elements, which can be slower. Also, dictionaries let you give meaningful names to data instead of relying on index numbers.

# %% [markdown]
# **12. Describe a scenario where using a tuple would be preferable over a list.**
#
#   -If you have data that should never change—like coordinates (x, y) or a date (date , month , year, place , time)—a tuple is better because it prevents accidental modifications.

# %% [markdown]
# **13. How do sets handle duplicate values in Python?**
#
#   -Sets automatically remove duplicate values. For example:

# %%
s = {1, 2, 2, 3}
print(s)
# Out:
# {1, 2, 3}

# %% [markdown]
# **14. How does the “in” keyword work differently for lists and dictionaries?**
#
#   -For lists, in checks if a value exists in the list by scanning it. This will make faster to find a specific value from a lenthier and bigger list.
#
#   -For dictionaries, in checks if a key exists, not a value.

# %%
nums = ["sid", "subin" , "sam"]
print("sam" in nums)  # here is the example for 'in' from in list.
# Out:
# True

# %%
person = {"name": "raj", "age": 45}
print("name" in person)
print("raj" in person)   # here is the example in dict.
# Out:
# True
# False

# %% [markdown]
# **15. Can you modify the elements of a tuple? Explain why or why not.**
#
#   -No, you can’t change the elements of a tuple because it is immutable. However, if the tuple contains a mutable object like a list, you can modify that object, but not the tuple itself.

# %% [markdown]
# **16. What is a nested dictionary, and give an example of its use case.**
#
#   -A nested dictionary is a dictionary inside another dictionary. It’s useful for storing structured data like student marks by subject:

# %%
grades = {
    "Khushi": {"Math": 90, "English": 85},
    "reena": {"Math": 78, "English": 92}
}

# %%
grades
# Out:
# {'Khushi': {'Math': 90, 'English': 85}, 'reena': {'Math': 78, 'English': 92}}

# %% [markdown]
# **17. Describe the time complexity of accessing elements in a dictionary.**
#
#   -Accessing elements in a dictionary is usually very fast because it uses hashing. In rare cases with many hash collisions, it could be , but that’s uncommon.

# %% [markdown]
# **18. In what situations are lists preferred over dictionaries?**
#
#   -Lists are preferred when you only need an ordered collection of items or when you don’t need key-value pairs. For example, if you just have a list of names, a list is simpler and uses less memory.

# %% [markdown]
# **19. Why are dictionaries considered unordered, and how does that affect data retrieval?**
#
#   -Dictionaries are considered unordered because the keys are not stored in sorted order. Since Python 3.7, they maintain the order in which keys were added, but this doesn’t mean they are sorted. This doesn’t affect retrieval because we always use keys, not positions.

# %% [markdown]
# **20. Explain the difference between a list and a dictionary in terms of data retrieval.**
#
#   -In a list, you access items using their index
#
# In a dictionary, you access items using keys. This makes dictionaries better when you need quick lookups using meaningful names.

# %%
my_list = [9]

# %%
my_dict=["kamal"]

# %% [markdown]
# # PRACTICAL QUESTIONS

# %%
#1. Write a code to create a string with your name and print it.

name = "Siddharth singh"
print(name)
# Out:
# Siddharth singh

# %%
#2. Write a code to find the length of the string "Hello World".

text = "Hello World"
print(len(text))
# Out:
# 11

# %%
#3. Write a code to slice the first 3 characters from the string "Python Programming".

text = "Python Programming"
print(text[:3])
# Out:
# Pyt

# %%
#4. Write a code to convert the string "hello" to uppercase.

text = "hello"
print(text.upper())
# Out:
# HELLO

# %%
#5. Write a code to replace the word "apple" with "orange" in the string "I like apple".

text = "I like apple"
new_text = text.replace("apple", "orange")
print(new_text)
# Out:
# I like orange

# %%
#6. Write a code to create a list with numbers 1 to 5 and print it.

numbers = [1, 2, 3, 4, 5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 7. Write a code to append the number 10 to the list [1, 2, 3, 4].

numbers = [1, 2, 3, 4]
numbers.append(10)
print(numbers)
# Out:
# [1, 2, 3, 4, 10]

# %%
#8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].

numbers = [1, 2, 3, 4, 5]
numbers.remove(3)
print(numbers)
# Out:
# [1, 2, 4, 5]

# %%
#9. Write a code to access the second element in the list ['a', 'b', 'c', 'd'].

letters = ['a', 'b', 'c', 'd']
print(letters[1])  # Index starts from 0
# Out:
# b

# %%
#10. Write a code to reverse the list [10, 20, 30, 40, 50].

numbers = [10, 20, 30, 40, 50]
numbers.reverse()
print(numbers)
# Out:
# [50, 40, 30, 20, 10]

# %%
#11. Create a tuple with the elements 100, 200, 300 and print it.

nums = (100, 200, 300)
print(nums)
# Out:
# (100, 200, 300)

# %%
#12. Access the second‑to‑last element of the tuple ('red', 'green', 'blue', 'yellow').

colors = ('red', 'green', 'blue', 'yellow')
print(colors[-2])  # second-to-last
# Out:
# blue

# %%
#13. Find the minimum number in the tuple (10, 20, 5, 15).

t = (10, 20, 5, 15)
print(min(t))
# Out:
# 5

# %%
#14. Find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

pets = ('dog', 'cat', 'rabbit')
print(pets.index("cat"))
# Out:
# 1

# %%
#15. Create a tuple containing three fruits and check if "kiwi" is in it.

fruits = ("apple", "banana", "mango")
print("kiwi" in fruits)  # True or False
# Out:
# False

# %%
#16. Create a set with the elements 'a', 'b', 'c' and print it.

letters = {'a', 'b', 'c'}
print(letters)
# Out:
# {'c', 'a', 'b'}

# %%
#17. Clear all elements from the set {1, 2, 3, 4, 5}.

s = {1, 2, 3, 4, 5}
s.clear()
print(s)  # empty set
# Out:
# set()

# %%
#18. Remove the element 4 from the set {1, 2, 3, 4}.

s = {1, 2, 3, 4}
s.remove(4)   # or s.discard(4) to avoid error if missing
print(s)
# Out:
# {1, 2, 3}

# %%
#19. Find the union of two sets {1, 2, 3} and {3, 4, 5}.

a = {1, 2, 3}
b = {3, 4, 5}
print(a | b)        # union
# print(a.union(b)) # same result
# Out:
# {1, 2, 3, 4, 5}

# %%
#20. Find the intersection of two sets {1, 2, 3} and {2, 3, 4}.

a = {1, 2, 3}
b = {2, 3, 4}
print(a & b)            # intersection
# print(a.intersection(b))
# Out:
# {2, 3}

# %%
#21. Create a dictionary with keys "name", "age", and "city", and print it.

person = {"name": "siddharth", "age": 23, "city": "Delhi"}
print(person)
# Out:
# {'name': 'siddharth', 'age': 23, 'city': 'Delhi'}

# %%
#22. Add "country": "USA" to the dictionary {'name': 'John', 'age': 25}.

person = {'name': 'John', 'age': 25}
person["country"] = "USA"
print(person)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
#23. Access the value for "name" in {'name': 'Alice', 'age': 30}.

person = {'name': 'Alice', 'age': 30}
print(person["name"])
# Out:
# Alice

# %%
#24. Remove the key "age" from {'name': 'Bob', 'age': 22, 'city': 'New York'}.

person = {'name': 'Bob', 'age': 22, 'city': 'New York'}
del person["age"]          # or person.pop("age")
print(person)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
#25. Check if the key "city" exists in {'name': 'Alice', 'city': 'Paris'}.

person = {'name': 'Alice', 'city': 'Paris'}
print("city" in person)  # True or False
# Out:
# True

# %%
#26. Create a list, a tuple, and a dictionary, and print them all.

my_list = [1, 2, 3]
my_tuple = (4, 5, 6)
my_dict = {"a": 1, "b": 2}
print(my_list, my_tuple, my_dict)
# Out:
# [1, 2, 3] (4, 5, 6) {'a': 1, 'b': 2}

# %%
#27. Create a list of 5 random numbers between 1 and 100, sort it, and print the result.

import random

nums = [random.randint(1, 100) for _ in range(5)]
nums.sort()
print(nums)
# Out:
# [11, 36, 71, 86, 96]

# %%
#28. Create a list with strings and print the element at the third index.

words = ["alpha", "beta", "gamma", "delta", "epsilon"]
print(words[3])  # element at index 3
# Out:
# delta

# %%
#29. Combine two dictionaries into one and print the result.

d1 = {"x": 1, "y": 2}
d2 = {"y": 99, "z": 3}
combined = d1 | d2       # if Python 3.9+
# combined = {**d1, **d2}  # works in earlier versions
print(combined)
# Out:
# {'x': 1, 'y': 99, 'z': 3}

# %%
#30. Convert a list of strings into a set.

names = ["Ana", "Bob", "Ana", "Cara"]
name_set = set(names)
print(name_set)  # duplicates removed
# Out:
# {'Ana', 'Bob', 'Cara'}
